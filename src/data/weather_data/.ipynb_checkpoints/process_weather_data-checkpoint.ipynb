# %%
import pandas as pd
from datetime import datetime

# %%
# Read .csv 
all_weather_data = pd.read_csv("/Users/eleshuk/Library/CloudStorage/GoogleDrive-eleshuk@gmail.com/.shortcut-targets-by-id/1XNkQR60z1T7WELqvqkvZchRrVWQpCzvs/data_science_project/Project Template/data/interim/Weather/20241229_all_weather_data.csv")

# %%
# Drop first four columns
all_weather_df = all_weather_data.drop(all_weather_data.columns[:4], axis=1)
all_weather_df.head()
# Out:
#                         date  temperature_2m_max  temperature_2m_min  \
# 0  2016-01-01 00:00:00+00:00           15.816500            9.616501
# 1  2016-01-02 00:00:00+00:00           13.966499            7.316500
# 2  2016-01-03 00:00:00+00:00           16.216500            8.816500
# 3  2016-01-04 00:00:00+00:00           16.016500           10.816500
# 4  2016-01-05 00:00:00+00:00           10.566500            6.516500
#
#    precipitation_sum municipality  latitude  longitude
# 0               10.2     Abrantes     39.43      -8.16
# 1                0.1     Abrantes     39.43      -8.16
# 2                3.5     Abrantes     39.43      -8.16
# 3                9.6     Abrantes     39.43      -8.16
# 4                4.7     Abrantes     39.43      -8.16

# %%
all_weather_df['date'] = pd.to_datetime(all_weather_df['date']).dt.strftime('%Y-%m-%d')

# %%
# Write to .csv
path = "/Users/eleshuk/Library/CloudStorage/GoogleDrive-eleshuk@gmail.com/.shortcut-targets-by-id/1XNkQR60z1T7WELqvqkvZchRrVWQpCzvs/data_science_project/Project Template/data/processed/Weather/cleaned_weather_data.csv"
all_weather_df.to_csv(path,index=False)

# %%
# Write to .csv
path = "/Users/eleshuk/Library/CloudStorage/GoogleDrive-eleshuk@gmail.com/.shortcut-targets-by-id/1XNkQR60z1T7WELqvqkvZchRrVWQpCzvs/data_science_project/Project Template/data/processed/Weather/cleaned_weather_data.csv"
weather_data = pd.read_csv(path)

# %%
# Add municipality ID
weather_data['MunicipalityID'] = pd.factorize(all_weather_df['municipality'])[0]
# Out:
#                date  temperature_2m_max  temperature_2m_min  \
# 1005371  2024-12-25           16.666500            8.766500
# 1005372  2024-12-26           18.116501            8.266500
# 1005373  2024-12-27           16.366501            7.516500
# 1005374  2024-12-28            8.966499            8.966499
# 1005375  2024-12-29                 NaN                 NaN
#
#          precipitation_sum municipality  latitude  longitude  MunicipalityID
# 1005371                0.0       Óbidos     39.36      -9.19             303
# 1005372                0.0       Óbidos     39.36      -9.19             303
# 1005373                0.0       Óbidos     39.36      -9.19             303
# 1005374                NaN       Óbidos     39.36      -9.19             303
# 1005375                NaN       Óbidos     39.36      -9.19             303

# %%
weather_cleaned = weather_data.dropna()

# %%
weather_cleaned = weather_cleaned.rename(columns={"date": "Date", "temperature_2m_max": "TemperatureMax", "temperature_2m_min": "TemperatureMin","precipitation_sum": "Precipitation"})
# Out:
#                Date  TemperatureMax  TemperatureMin  Precipitation  \
# 0        2016-01-01       15.816500        9.616501           10.2
# 1        2016-01-02       13.966499        7.316500            0.1
# 2        2016-01-03       16.216500        8.816500            3.5
# 3        2016-01-04       16.016500       10.816500            9.6
# 4        2016-01-05       10.566500        6.516500            4.7
# ...             ...             ...             ...            ...
# 1005369  2024-12-23       15.066500        7.866500            0.0
# 1005370  2024-12-24       16.166500        7.416500            0.0
# 1005371  2024-12-25       16.666500        8.766500            0.0
# 1005372  2024-12-26       18.116501        8.266500            0.0
# 1005373  2024-12-27       16.366501        7.516500            0.0
#
#         municipality  latitude  longitude  MunicipalityID
# 0           Abrantes     39.43      -8.16               0
# ...

# %%
# Drop specific columns
columns_to_drop = ['latitude', 'longitude']
weather_cleaned = weather_cleaned.drop(columns=columns_to_drop, axis=1)

# %%
# Write to .csv
path = "/Users/eleshuk/Library/CloudStorage/GoogleDrive-eleshuk@gmail.com/.shortcut-targets-by-id/1XNkQR60z1T7WELqvqkvZchRrVWQpCzvs/data_science_project/Project Template/data/interim/Weather/cleaned_weather_data_wrong_municipalitiesID.csv"
weather_cleaned.to_csv(path,index=False)
